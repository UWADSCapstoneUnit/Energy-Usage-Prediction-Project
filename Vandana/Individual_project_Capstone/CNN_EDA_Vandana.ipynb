# %%
import pathlib
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()


# %matplotlib inline
import holidays
import pathlib
import datetime
from os import PathLike
from typing import Union

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
from pandas.plotting import register_matplotlib_converters

import palettable
from matplotlib.colors import ListedColormap
import seaborn as sns
# %matplotlib inline

#from scipy.stats import linregress
#import pymc3 as pm


#plt.style.use('grayscale')
# Custom Overrides to grayscale
params = {'legend.fontsize': 'x-large',
          'lines.linewidth': 0.75,
      'figure.figsize': (15, 7),
          'grid.color': 'white',
          'axes.axisbelow': False,
          'axes.grid': True,
          'axes.grid.axis': 'y',
     'axes.labelsize': 'x-large',
     'axes.titlesize':'xx-large',
     'xtick.labelsize':'x-large',
     'ytick.labelsize':'x-large'}
plt.rcParams.update(params)
figsize=(15,7)

# %%
#import libraries
import pandas as pd
import numpy as np
from numpy import array
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
plt.style.use('fivethirtyeight')
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set_style("darkgrid")
sns.set_context("poster")

import holidays
from sklearn import feature_selection as fs
from sklearn import model_selection as ms

# %%
df = pd.read_csv('One_hr_data.csv')
df.head()
# Out:
#         timestamp    demand   temp  dew_point  humidity  wind_speed  pressure  \
# 0  1/01/2017 0:00  3474.570  21.11       7.78        43          10        29
# 1  1/01/2017 1:00  3371.978  21.11       7.22        40          21        29
# 2  1/01/2017 2:00  3287.374  20.00       7.78        46          20        29
# 3  1/01/2017 3:00  3218.992  17.78       8.89        56          20        29
# 4  1/01/2017 4:00  3203.696  17.22       8.89        59          23        29
#
#       condition
# 0          Fair
# 1  Fair / Windy
# 2          Fair
# 3          Fair
# 4  Fair / Windy

# %%
df.rename(columns={"timestamp" : 'Date'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#                      Date    demand   temp  dew_point  humidity  wind_speed  \
# 0     2017-01-01 00:00:00  3474.570  21.11       7.78        43          10
# 1     2017-01-01 01:00:00  3371.978  21.11       7.22        40          21
# 2     2017-01-01 02:00:00  3287.374  20.00       7.78        46          20
# 3     2017-01-01 03:00:00  3218.992  17.78       8.89        56          20
# 4     2017-01-01 04:00:00  3203.696  17.22       8.89        59          23
# ...                   ...       ...    ...        ...       ...         ...
# 45427 2022-08-03 19:00:00  6038.368  23.90      15.00        57          13
# 45428 2022-08-03 20:00:00  5602.400  23.90      15.00        57          13
# 45429 2022-08-03 21:00:00  5109.266  23.90      15.00        57          13
# 45430 2022-08-03 22:00:00  4613.252  23.90      15.00        57          13
# 45431 2022-08-03 23:00:00  4249.630  23.90      15.00        57          13
#
#        pressure     condition
# 0            29          Fair
# 1            29  Fair / Windy
# 2            29          Fair
# 3            29          Fair
# 4            29  Fair / Windy
# ...         ...           ...
# 45427        29          Fair
# 45428        29          Fair
# 45429        29          Fair
# 45430        29          Fair
# 45431        29          Fair
#
# [45432 rows x 8 columns]

# %% [markdown]
# ## Checking Data structure

# %%
df.info
# Out:
# <bound method DataFrame.info of                      Date    demand   temp  dew_point  humidity  wind_speed  \
# 0     2017-01-01 00:00:00  3474.570  21.11       7.78        43          10
# 1     2017-01-01 01:00:00  3371.978  21.11       7.22        40          21
# 2     2017-01-01 02:00:00  3287.374  20.00       7.78        46          20
# 3     2017-01-01 03:00:00  3218.992  17.78       8.89        56          20
# 4     2017-01-01 04:00:00  3203.696  17.22       8.89        59          23
# ...                   ...       ...    ...        ...       ...         ...
# 45427 2022-08-03 19:00:00  6038.368  23.90      15.00        57          13
# 45428 2022-08-03 20:00:00  5602.400  23.90      15.00        57          13
# 45429 2022-08-03 21:00:00  5109.266  23.90      15.00        57          13
# 45430 2022-08-03 22:00:00  4613.252  23.90      15.00        57          13
# 45431 2022-08-03 23:00:00  4249.630  23.90      15.00        57          13
#
#        pressure     condition
# 0            29          Fair
# 1            29  Fair / Windy
# 2            29          Fair
# 3            29          Fair
# 4            29  Fair / Windy
# ...         ...           ...
# 45427        29          Fair
# 45428        29          Fair
# 45429        29          Fair
# 45430        29          Fair
# 45431        29          Fair
#
# [45432 rows x 8 columns]>

# %%
df.dtypes
# Out:
# Date          datetime64[ns]
# demand               float64
# temp                 float64
# dew_point            float64
# humidity               int64
# wind_speed             int64
# pressure               int64
# condition             object
# dtype: object

# %%
df.shape
# Out:
# (45432, 8)

# %%
df.isnull().sum()
# Out:
# Date          0
# demand        0
# temp          0
# dew_point     0
# humidity      0
# wind_speed    0
# pressure      0
# condition     0
# dtype: int64

# %% [markdown]
# # Visual Inspection

# %%
plt.figure(figsize=(30,15))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Demand Overview

# %%
# Plot the time series
ax = df.plot(y="demand", figsize=[20, 10], legend=False)
ax.set_ylabel("Demand (MW)")
ax.set_xlabel("Time")
ax.set_title("Electricity demand from 2017 to 2022")
plt.tight_layout()

# %%
# Plot the time series
ax = df[-2352:].plot(y="demand", figsize=[20, 10], legend=False)
ax.set_ylabel("Demand (MW)")
ax.set_xlabel("Time")
ax.set_title("Electricity demand summer 2022")
plt.tight_layout()

# %%
# Plot the time series
ax = df[-168:].plot(y="demand", figsize=[20, 10], legend=False)
ax.set_ylabel("Demand (MW)")
ax.set_xlabel("Time")
ax.set_title("Electricity demand for a week")
plt.tight_layout()

# %% [markdown]
# # Verify Data integrity, and Identify Problems

# %%
plt.boxplot(df.loc[:,"demand"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2468ff192e0>,
#   <matplotlib.lines.Line2D at 0x2468ff19670>],
#  'caps': [<matplotlib.lines.Line2D at 0x2468ff19a00>,
#   <matplotlib.lines.Line2D at 0x2468ff19d90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2468ff06f10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2468ff27160>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2468ff274f0>],
#  'means': []}

# %%
#creating a separate data for weekly and monthly analysis
df1 = df.copy()
df1['Date'] = pd.to_datetime(df1['Date'], format="%Y-%m-%d %H")
df1 = df1.interpolate(method='bfill')
df1 = df1.interpolate(method='ffill')

# %%
df1['hour'] = df1['Date'].dt.hour
df1['day'] = df1['Date'].dt.dayofyear
df1['week'] = df1['Date'].dt.week
df1['month'] = df1['Date'].dt.month
df1['weekday'] = df1['Date'].dt.day_name()
df1["day_of_month"] = df1['Date'].dt.day

#dictionary for useful variables

AU_holidays = holidays.AUS()
df1['holiday'] = [1 if d in AU_holidays else 0 for d in df1['Date']]
df1[df1['holiday'] == 1]

df1['isWorkDay'] = df1.apply(lambda x: 'no' if ((x['holiday'] == 1) or
                                          (x['weekday'] in ['Sunday', 'Saturday'])) else 'yes', axis=1)

cat_cols = ['hour','day','week','month','weekday','holiday','isWorkDay','condition']
for col in cat_cols:
  df1[col] = df1[col].astype('category')

# %%
df1
# Out:
#                      Date    demand   temp  dew_point  humidity  wind_speed  \
# 0     2017-01-01 00:00:00  3474.570  21.11       7.78        43          10
# 1     2017-01-01 01:00:00  3371.978  21.11       7.22        40          21
# 2     2017-01-01 02:00:00  3287.374  20.00       7.78        46          20
# 3     2017-01-01 03:00:00  3218.992  17.78       8.89        56          20
# 4     2017-01-01 04:00:00  3203.696  17.22       8.89        59          23
# ...                   ...       ...    ...        ...       ...         ...
# 45427 2022-03-08 19:00:00  6038.368  23.90      15.00        57          13
# 45428 2022-03-08 20:00:00  5602.400  23.90      15.00        57          13
# 45429 2022-03-08 21:00:00  5109.266  23.90      15.00        57          13
# 45430 2022-03-08 22:00:00  4613.252  23.90      15.00        57          13
# 45431 2022-03-08 23:00:00  4249.630  23.90      15.00        57          13
#
#        pressure     condition hour day week month  weekday  day_of_month  \
# 0            29          Fair    0   1   52     1   Sunday             1
# 1            29  Fair / Windy    1   1   52     1   Sunday             1
# 2            29          Fair    2   1   52     1   Sunday             1
# 3            29          Fair    3   1   52     1   Sunday             1
# 4            29  Fair / Windy    4   1   52     1   Sunday             1
# ...         ...           ...  ...  ..  ...   ...      ...           ...
# 45427        29          Fair   19  67   10     3  Tuesday             8
# 45428        29          Fair   20  67   10     3  Tuesday             8
# 45429        29          Fair   21  67   10     3  Tuesday             8
# 45430        29          Fair   22  67   10     3  Tuesday             8
# 45431        29          Fair   23  67   10     3  Tuesday             8
#
#       holiday isWorkDay
# 0           1        no
# 1           1        no
# 2           1        no
# 3           1        no
# 4           1        no
# ...       ...       ...
# 45427       0       yes
# 45428       0       yes
# 45429       0       yes
# 45430       0       yes
# 45431       0       yes
#
# [45432 rows x 16 columns]

# %%
# Plot the electricity demand for each day
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=[15, 10], sharey=True)
ax = ax.flatten()
sns_blue = sns.color_palette(as_cmap=True)[0]
MONTHS = ["Dec","Jan", "Feb"]
for ix, month in enumerate(MONTHS):

    # Plot individual ts
    daily_ts = []
    for _, ts in (
        df1[["demand", "day_of_month", "month"]]
        .query(f"month == {ix+1}")
        .groupby("day_of_month")
    ):
        daily_ts.append(ts.reset_index()["demand"])
        ts.reset_index()["demand"].plot(
            alpha=0.1, ax=ax[ix], color=sns_blue, label="_no_legend_"
        )
        #ax[ix].set_xticks(np.arange(0, len(ts) + 1, 8))
        ax[ix].set_title(month)

    # Plot the mean ts
    pd.concat(daily_ts, axis=1).mean(axis=1).plot(
        ax=ax[ix], color="blue", label="mean", legend=True
    )
    ax[ix].legend(loc="upper left", frameon=False)

    

#fig.text(0.5, -0.02, "Hour of day", ha="center")
fig.text(-0.02, 0.5, "Demand (MW)", va="center", rotation="vertical")
fig.suptitle("Daily electricity demand in summer by month")
fig.delaxes(ax[-1])
fig.tight_layout()

# %%
plt.hist(df1["demand"])
# Out:
# (array([  157.,  1310.,  9510., 16057., 10365.,  5104.,  1975.,   693.,
#           198.,    63.]),
#  array([1536.858 , 2178.4774, 2820.0968, 3461.7162, 4103.3356, 4744.955 ,
#         5386.5744, 6028.1938, 6669.8132, 7311.4326, 7953.052 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Check Peak Data against Alternate Source

# %% [markdown]
# Lets check this with weather data set

# %% [markdown]
# # Weather Overview

# %% [markdown]
# # Relationship Between Temperature and Power Demand

# %%
max_demand = pd.read_csv('max_demand.csv', index_col=0, parse_dates=True)
#df_merged['timestamp']= pd.to_datetime(df_merged['timestamp'])
max_demand.head()
# Out:
#             Operational Demand (MW) Transpiration Rain Evaporation  Max Temp  \
# Date
# 2009-01-01                 2543.140          11.2    0        11.6      37.2
# 2009-02-01                 2893.868          10.2    0        12.8      36.1
# 2009-03-01                 2450.920           9.4    0        11.8      34.4
# 2009-04-01                 2526.302          10.5    0        11.2      36.5
# 2009-05-01                 3106.014          11.9    0        11.4      37.2
#
#            Min Temp Max Hum Min Hum Av Wind Solar Rad  Year  month  \
# Date
# 2009-01-01     18.8      65      20     6.1     34.01  2009      1
# 2009-02-01     21.9      70      25    5.31     34.25  2009      1
# 2009-03-01     20.3      79      29    5.45     34.11  2009      1
# 2009-04-01     18.5      62      20    5.25     34.05  2009      1
# 2009-05-01     21.8      63      17    6.77     34.18  2009      1
#
#             Day_of_week  Day_of_month  Day_of_year  week_of_year  \
# Date
# 2009-01-01            3             1            1             1
# 2009-02-01            4             2            2             1
# 2009-03-01            5             3            3             1
# 2009-04-01            6             4            4             1
# 2009-05-01            0             5            5             2
#
#             state_holiday  mnth_sin  mnth_cos
# Date
# 2009-01-01           True       0.0       1.0
# 2009-02-01          False       0.0       1.0
# 2009-03-01          False       0.0       1.0
# 2009-04-01          False       0.0       1.0
# 2009-05-01          False       0.0       1.0

# %%
max_demand['daytype'] = ['Weekday' if x<5 else 'Weekend' for x in max_demand['Day_of_week']]
max_demand
# Out:
#             Operational Demand (MW) Transpiration  Rain Evaporation  Max Temp  \
# Date
# 2009-01-01                 2543.140          11.2     0        11.6      37.2
# 2009-02-01                 2893.868          10.2     0        12.8      36.1
# 2009-03-01                 2450.920           9.4     0        11.8      34.4
# 2009-04-01                 2526.302          10.5     0        11.2      36.5
# 2009-05-01                 3106.014          11.9     0        11.4      37.2
# ...                             ...           ...   ...         ...       ...
# 2022-11-08                 3061.642           2.2     0         1.4      19.6
# 2022-12-08                 2812.890           3.5     0           2      21.0
# 2022-08-13                 2921.720           2.9     0           4      16.8
# 2022-08-14                 2785.140           2.3  16.2         1.8      19.5
# 2022-08-15                 2575.118           3.5     0         1.8      23.5
#
#            Min Temp Max Hum Min Hum Av Wind Solar Rad  Year  month  \
# Date
# 2009-01-01     18.8      65      20     6.1     34.01  2009      1
# 2009-02-01     21.9      70      25    5.31     34.25  2009      1
# 2009-03-01     20.3      79      29    5.45     34.11  2009      1
# 2009-04-01     18.5      62      20    5.25     34.05  2009      1
# 2009-05-01     21.8      63      17    6.77     34.18  2009      1
# ...             ...     ...     ...     ...       ...   ...    ...
# 2022-11-08      2.8      96      43     1.9      15.3  2022      8
# 2022-12-08        6      92      41     5.4     15.42  2022      8
# 2022-08-13     10.9      94      34    5.97      5.67  2022      8
# 2022-08-14      7.3      96      47    2.62     13.35  2022      8
# 2022-08-15     10.1      94      43    4.49     15.55  2022      8
#
#             Day_of_week  Day_of_month  Day_of_year  week_of_year  \
# Date
# 2009-01-01            3             1            1             1
# 2009-02-01            4             2            2             1
# 2009-03-01            5             3            3             1
# 2009-04-01            6             4            4             1
# 2009-05-01            0             5            5             2
# ...                 ...           ...          ...           ...
# 2022-11-08            3            11          223            32
# 2022-12-08            4            12          224            32
# 2022-08-13            5            13          225            32
# 2022-08-14            6            14          226            32
# 2022-08-15            0            15          227            33
#
#             state_holiday  mnth_sin  mnth_cos  daytype
# Date
# 2009-01-01           True       0.0  1.000000  Weekday
# 2009-02-01          False       0.0  1.000000  Weekday
# 2009-03-01          False       0.0  1.000000  Weekend
# 2009-04-01          False       0.0  1.000000  Weekend
# 2009-05-01          False       0.0  1.000000  Weekday
# ...                   ...       ...       ...      ...
# 2022-11-08          False      -0.5 -0.866025  Weekday
# 2022-12-08          False      -0.5 -0.866025  Weekday
# 2022-08-13          False      -0.5 -0.866025  Weekend
# 2022-08-14          False      -0.5 -0.866025  Weekend
# 2022-08-15          False      -0.5 -0.866025  Weekday
#
# [4970 rows x 20 columns]

# %%
max_demand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4970 entries, 2009-01-01 to 2022-08-15
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Operational Demand (MW)  4970 non-null   float64
#  1   Transpiration            4970 non-null   object
#  2   Rain                     4970 non-null   object
#  3   Evaporation              4970 non-null   object
#  4   Max Temp                 4970 non-null   float64
#  5   Min Temp                 4970 non-null   object
#  6   Max Hum                  4970 non-null   object
#  7   Min Hum                  4970 non-null   object
#  8   Av Wind                  4970 non-null   object
#  9   Solar Rad                4970 non-null   object
#  10  Year                     4970 non-null   int64
#  11  month                    4970 non-null   int64
#  12  Day_of_week              4970 non-null   int64
#  13  Day_of_month             4970 non-null   int64
#  14  Day_of_year              4970 non-null   int64
#  15  week_of_year             4970 non-null   int64
#  16  state_holiday            4970 non-null   bool
#  17  mnth_sin                 4970 non-null   float64
#  18  mnth_cos                 4970 non-null   float64
#  19  daytype                  4970 non-null   object
# dtypes: bool(1), float64(4), int64(6), object(9)
# memory usage: 781.4+ KB

# %%
#max_demand['Max Temp']= max_demand['Max Temp'].astype(float)

# %%
colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple"]
sns.set_palette(sns.xkcd_palette(colors))
fig, ax = plt.subplots(frameon=False, figsize=(13,13))
sns.scatterplot(x="Max Temp", y="Operational Demand (MW)",
                hue="daytype",
                hue_order=['Weekend', 'Weekday'],
                data=max_demand, ax=ax, legend='full')
#plt.title('')
ax.set_ylabel('Megawatts (MW)')
ax.set_xlabel('Temperature (C)')
ax.set_title('Power Demand vs Temperature - Hourly Weekdays (Mon-Fri) and Weekends (Sat & Sun)')
plt.show();

# %% [markdown]
# # Power Demand Distribution - Summer

# %%
# Put histogram here and identify dual peak
bins=int(np.sqrt(len(y)))
fig, ax = plt.subplots(figsize=(14,8))
ax.hist(y, bins = bins, density=True)
ax.set_ylabel('Probability')
ax.set_xlabel('Megawatts')
ax.set_title('Daily Peak Power Demand - Summer ')
plt.show();

# %%
fig, ax = plt.subplots(figsize=(14,8))
ax.set_xlabel('Megawatts')
ax.set_ylabel('Prob.')
sns.kdeplot(y, ax=ax);

# %% [markdown]
# # Temperature - Summer

# %%
fig, ax = plt.subplots(figsize=(14,8))
ax.set_xlabel('Temperature')
ax.set_ylabel('Prob.')
sns.kdeplot(x, ax=ax);
